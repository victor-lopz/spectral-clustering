# %% [markdown]
# ### Dibuixa trajectòries pel sistema de Duffing no autònom

# %%
import sys
sys.path.append("..")
from src import *
import numpy as np
np.set_printoptions(precision=3, suppress=True)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
params = ParametresGenerals(
    dimensio=2,
    t_span=(0, 20),
    t_steps=3000,
    x_min=-1,
    x_max=1,
    y_min=-0.5,
    y_max=0.5,
    espai_entre_punts=1,
    max_clusters=50,
    num_radis=50
    )

# %%
# condicions_inicials = np.array([[-1.0, -0.75], [0.55, 0.65], [0.02, 0.0]])
condicions_inicials = np.array([[-1.0, -0.75], [0.55, 0.65]])
num_trajectories = len(condicions_inicials)
trajectories = generar_trajectories(edo_duffing_no_autonom, condicions_inicials, params)
print("(Num trajectories, t_steps, dimensio) =", trajectories.shape)
grafica_trajectories(trajectories, subfolder="no_autonom")
# Out:
# (Num trajectories, t_steps, dimensio) = (2, 3000, 2)
